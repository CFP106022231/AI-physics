# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # AIphysics Higgs production

# %% [markdown]
# ## Data visualization we do before

# %% [markdown]
# ### 1. heat map

# %% [markdown]
# ![image.png](attachment:7e857238-d548-4f1c-82dd-a09559a4cb26.png)

# %% [markdown]
# ### 2. High Level Features

# %% [markdown]
# ![image.png](attachment:af7c596b-1f0f-4eb4-94f4-de94bc5e4eb6.png)

# %% [markdown]
# ### 3. low Level Features

# %% [markdown]
# ![image.png](attachment:dc768e39-6346-4f5d-aadb-e44864475c9d.png)

# %% [markdown]
# (1) About what we analysis before:
#
# **High-level-features** may have a better training performance since each features for four Higgs productions jets are more distinguishable in high-level-features.
#
#
#
# (2) what can we do on this data:
#
# **classification**: train a model that can distunguish four Higgs productions jets

# %% [markdown]
# # our plan
# 1. first, read the paper to more understand the physical meaning behind the data.
# 2. after we know the physical meaning behind the data, we can choose suitable feature to analysis
# 3. also, we can use the result which we do previous class
# 4. analysis the data and try to find suitable model to classify them
# 5.

# %% [markdown]
# # outline
#
# 1. Introduction
# - Introduce physics behind data
# - 4 modes of higg
#
# 2. motivation
# - Since the Higgs boson was discovered in 2012, we have to find the technique to distinguish them.
# - we get four labels in out data, which means four kinds of different modes of Higgs boson, so we want to do classification to distinguish four modes.
#
# 3. Data exploration
#
# 4. Proposal of ML study
# - Explain the ML classifiers we used to classify the four Higgs production modes.

# %% [markdown]
# comment
# Know how to calculate high level feature & produce image
# and write it on the final report (can be assigned with another group)

# %% [markdown]
# # 6/2

# %% [markdown]
# # new comment
# Know how to calculate high level feature & produce image from low level feature
# and write it on the final report (can be assigned with another group)

# %% [markdown]
# # DNN
# We try to use DNN model, and figure below is our model. We use Relu to be activation funtion, and output is sigmoid.
#
# I think the result still have something wrong and need to be improve. We also still don't know how to optimize the model and select parameters.
#
# We will continue to work on it.
#
# ![image.png](attachment:4c828ccc-4f05-4355-96e5-1c07e27ec1c0.png)
#
# ![image.png](attachment:fb50aebe-c9dc-4a1c-8bf8-c35afe3da6b8.png)
# ![image.png](attachment:08b39962-d51c-4776-a34e-114a281b581e.png)

# %% [markdown]
# # TREE
# we chhose high level feature to analyize
# but it still need to fix

# %% [markdown]
# ![image.png](attachment:2c4da341-f063-435c-943d-1400e5765a63.png)

# %% [markdown]
# ![image.png](attachment:ab6c4e82-10bd-4e71-a687-23334f13620c.png)

# %% [markdown]
# # 6/9

# %% [markdown]
# ## newfound

# %% [markdown]
# 1. May need to reallocate train data and test data
# 2. Try to find out how to calculate high level feature
# [Higgs-Classification/analysis/function.py](https://github.com/alan200276/Higgs-Classification/blob/master/analysis/function.py)
# [Higgs-Classification/analysis/Data_Preprocessing.py](https://github.com/alan200276/Higgs-Classification/blob/master/analysis/Data_Preprocessing.py)
# 3.

# %% [markdown]
# ## Tree

# %% [markdown]
# So when we use the decision tree to test the data, we first merge the original "Train_Data_HLF" and "Test_Data_HLF"
# and then use "train_test_split" to do reseparate data.
#
# To reduce the use of data first (because the computer will run too long with all the data),
# so the split data will be used separately for random number selection by "sample".
#
# Finally, we use this data to test and get the following results:

# %% [markdown]
# ![image.png](attachment:ea5ba270-efab-4dd9-abb1-82b17ce54191.png)

# %% [markdown]
# ![image.png](attachment:7058a377-31ba-4f33-84d6-f64020e99f21.png)
