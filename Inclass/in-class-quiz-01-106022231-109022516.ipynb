# %% [markdown]
# 1. Introduce yourself to your teammate (look up your teammate from the in-class Quiz).
#   * What is your nickname on Discord?
#   * What was your data analysis experiences?
#   * What are your current research projects?
#   * What skills do you want to learn in this course?

# %% [markdown]
# 2. Student **A** should Copy and Edit this Notebook in Kaggle. Rename it to "In-class Quiz 01_[StudentID A]_[StudentID B]." Share it to Student B and NTHU-AIPHYS2021.

# %% [markdown]
# Let's start the first exercise.

# %% [markdown]
# Example1: load `X_Train.csv` as example and show them how we do it

# %%
import os
import pandas as pd
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/phys591000-week01/X_Test.csv
# /kaggle/input/phys591000-week01/X_Train.csv
# /kaggle/input/phys591000-week01/X_Val.csv
# /kaggle/input/phys591000-week01/Target_Val.csv
# /kaggle/input/phys591000-week01/Target_Train.csv

# %%
X_Train = pd.read_csv("/kaggle/input/phys591000-week01/X_Train.csv")

# %% [markdown]
# Exercise1: please load `X_Val.csv` and `X_test.csv`

# %%
X_Val = pd.read_csv("/kaggle/input/phys591000-week01/X_Val.csv")
X_Test = pd.read_csv("/kaggle/input/phys591000-week01/X_Test.csv")

# %% [markdown]
# Example2: number in the column

# %%
X_Train.describe()
# Out:
#                MJ_0         PTJ_0         t21_0         D21_0         D22_0  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean     112.834582    375.297821      0.529895      3.419551     20.991948
# std       43.658239     46.937815      0.221046      3.049440     49.767911
# min       14.367482    301.462945      0.054913      0.236369      0.055870
# 25%       86.440793    337.597249      0.346873      1.557822      2.426808
# 50%      103.480039    364.067834      0.522033      2.284578      5.219297
# 75%      128.207078    405.256400      0.711498      4.178760     17.462037
# max      397.558437    499.906803      0.987836     40.065662   1605.257243
#
#               C21_0         C22_0            MJ           PTJ           t21  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       0.321205      0.113938     73.867590    356.624809      0.435594
# ...

# %% [markdown]
# Exercise2: Pleas show column structures for `X_Val.csv` and `X_test.csv`.

# %%
X_Val.describe()
# Out:
#                MJ_0         PTJ_0         t21_0         D21_0         D22_0  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean     113.071810    374.517073      0.534999      3.451251     21.963476
# std       43.639793     46.627498      0.220244      3.170622     80.219460
# min       15.158735    300.965104      0.047301      0.245221      0.060133
# 25%       86.919129    337.241109      0.352744      1.591177      2.531844
# 50%      104.037689    363.378513      0.527533      2.299911      5.289589
# 75%      128.482286    403.878633      0.720187      4.168510     17.376477
# max      399.492841    499.992604      0.980976     84.919810   7211.374192
#
#               C21_0         C22_0            MJ           PTJ           t21  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       0.324576      0.116056     73.491647    355.695003      0.440522
# ...

# %%
X_Test.describe()
# Out:
#                MJ_0         PTJ_0         t21_0         D21_0         D22_0  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean     113.366607    374.934585      0.530293      3.399118     21.010748
# std       43.892419     46.540887      0.219491      3.075336     62.090936
# min       16.489934    300.965104      0.070752      0.282768      0.079958
# 25%       86.655315    337.177725      0.348724      1.570184      2.465479
# 50%      104.016093    363.951608      0.521615      2.276644      5.183107
# 75%      129.190655    405.319987      0.711325      4.065580     16.528940
# max      368.745259    499.827972      0.983213     62.244711   3874.403989
#
#               C21_0         C22_0            MJ           PTJ           t21  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       0.322791      0.114943     74.254987    356.149164      0.436309
# ...
